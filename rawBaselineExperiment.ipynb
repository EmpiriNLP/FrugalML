# %%
import json
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def initialize_model():
    model_name = "microsoft/Phi-3-mini-4k-instruct"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        device_map="auto"
    )
    return model, tokenizer

def load_finqa_dataset(path):
    with open(path, "r") as f:
        return json.load(f)

def simple_inference(example, model, tokenizer):
    """Generate numerical answers with minimal context and clear instruction"""
    question = example["qa"]["question"]
    
    # Extract only the most relevant information from FinQA
    relevant_info = " ".join(example["qa"].get("gold_inds", {}).values())

    # Ensure the model knows it's supposed to return ONLY a number
    input_text = (
        "You are a financial calculator. "
        "Read the question carefully and return ONLY the final numerical answer without explanation.\n\n"
        f"Relevant Information:\n{relevant_info}\n\n"
        f"Question: {question}\n"
        "Final Answer (number only): "
    )

    inputs = tokenizer(input_text, return_tensors="pt", truncation=True).to(model.device)

    with torch.no_grad():
        output = model.generate(
            **inputs,
            max_new_tokens=10,
            num_beams=1,  # No beam search
            do_sample=False  # Ensure deterministic output
        )

    return tokenizer.decode(output[0], skip_special_tokens=True).strip()

def evaluate_baseline(test_data, model, tokenizer, num_samples=10):
    """Simple evaluation loop"""
    for i, example in enumerate(test_data[:num_samples]):
        try:
            prediction = simple_inference(example, model, tokenizer)
            ground_truth = example["qa"]["answer"]
            
            print(f"\nExample {i+1}")
            print(f"Question: {example['qa']['question']}")
            print(f"Ground Truth: {ground_truth}")
            print(f"Raw Prediction: {prediction}")
            
        except Exception as e:
            print(f"Error processing example {i}: {str(e)}")

def main():
    model, tokenizer = initialize_model()
    print("Model initialized successfully!")
    
    test_data = load_finqa_dataset("/cs/student/projects2/aisd/2024/giliev/FinQA/dataset/test.json")
    print("Dataset loaded successfully!")
    
    evaluate_baseline(test_data, model, tokenizer)

if __name__ == "__main__":
    main()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Model initialized successfully!
# Dataset loaded successfully!
#
# Example 1
# Question: what is the net change in net revenue during 2015 for entergy corporation?
# Ground Truth: 94
# Raw Prediction: You are a financial calculator. Read the question carefully and return ONLY the final numerical answer without explanation.
#
# Relevant Information:
# the 2014 net revenue of amount ( in millions ) is $ 5735 ; the 2015 net revenue of amount ( in millions ) is $ 5829 ;
#
# Question: what is the net change in net revenue during 2015 for entergy corporation?
# Final Answer (number only): 94
#
# Relevant Information:
# the
#
# Example 2
# Question: what percentage of total facilities as measured in square feet are leased?
# Ground Truth: 14%
# Raw Prediction: You are a financial calculator. Read the question carefully and return ONLY the final numerical answer without explanation.
#
# Relevant Information:
# ( square feet in millions ) the leased facilities2 of unitedstates is 2.1 ; the leased facilities2 of othercountries is 6.0 ; the leased facilities2 of total is 8.1 ; ( square feet in millions ) the total facilities of unitedstates is 32.8 ; the total facilities of othercountries is 23.2 ; the total facilities of total is 56.0 ;
#
# Question: what percentage of total facilities as measured in square feet are leased?
# Final Answer (number only): 14.4%
#
#
# Question:
#
# Example 3
# Question: what is the percentage change in cash flow hedges in 2011 compare to the 2010?
# Ground Truth: 9.9%
# Raw Prediction: You are a financial calculator. Read the question carefully and return ONLY the final numerical answer without explanation.
#
# Relevant Information:
# the total notional amounts of derivative instruments designated as hedging instruments as of october 29 , 2011 and october 30 , 2010 were $ 375 million of interest rate swap agreements accounted for as fair value hedges and $ 153.7 million and $ 139.9 million , respectively , of cash flow hedges denominated in euros , british pounds and analog devices , inc .
#
# Question: what is the percentage change in cash flow hedges in 2011 compare to the 2010?
# Final Answer (number only): 13.05%
#
# Relevant
#
# Example 4
# Question: what portion of total purchase price is related to stock awards?
# Ground Truth: 2.9%
# Raw Prediction: You are a financial calculator. Read the question carefully and return ONLY the final numerical answer without explanation.
#
# Relevant Information:
# value of metavante common stock the value of metavante stock awards of $ 4066.4 is 121.4 ; value of metavante common stock the total purchase price of $ 4066.4 is $ 4187.8 ;
#
# Question: what portion of total purchase price is related to stock awards?
# Final Answer (number only): 121.4
#
# Relevant Information
#
# Example 5
# Question: what was the difference in percentage cumulative total shareholder return on masco common stock versus the s&p 500 index for the five year period ended 2017?
# Ground Truth:
# Raw Prediction: You are a financial calculator. Read the question carefully and return ONLY the final numerical answer without explanation.
#
# Relevant Information:
# the masco of 2013 is $ 138.48 ; the masco of 2014 is $ 155.26 ; the masco of 2015 is $ 200.79 ; the masco of 2016 is $ 227.08 ; the masco of 2017 is $ 318.46 ; the s&p 500 index of 2013 is $ 132.04 ; the s&p 500 index of 2014 is $ 149.89 ; the s&p 500 index of 2015 is $ 151.94 ; the s&p 500 index of 2016 is $ 169.82 ; the s&p 500 index of 2017 is $ 206.49 ;
#
# Question: what was the difference in percentage cumulative total shareholder return on masco common stock versus the s&p 500 index for the five year period ended 2017?
# Final Answer (number only): 100.00%
#
# Example 6
# Question: what was the percentage change in total rental expense under operating leases from july 2 , 2005 to july 1 , 2006?
# Ground Truth: 7%
# Raw Prediction: You are a financial calculator. Read the question carefully and return ONLY the final numerical answer without explanation.
#
# Relevant Information:
# total rental expense under operating leases was $ 100690000 , $ 92710000 , and $ 86842000 in fiscal 2006 , 2005 and 2004 , respectively .
#
# Question: what was the percentage change in total rental expense under operating leases from july 2 , 2005 to july 1 , 2006?
# Final Answer (number only): 9.05%
#
#
# Question:
#
# Example 7
# Question: what percent of total recourse debt is current?
# Ground Truth: 10%
# Raw Prediction: You are a financial calculator. Read the question carefully and return ONLY the final numerical answer without explanation.
#
# Relevant Information:
# december 31 , the 2011 of annual maturities ( in millions ) is $ 463 ; december 31 , the total recourse debt of annual maturities ( in millions ) is $ 4612 ;
#
# Question: what percent of total recourse debt is current?
# Final Answer (number only): 0.1%
#
# Relevant Information:
#
# Example 8
# Question: what percentage of future minimum rental payments are due in 2018?
# Ground Truth: 12%
# Raw Prediction: You are a financial calculator. Read the question carefully and return ONLY the final numerical answer without explanation.
#
# Relevant Information:
# $ in millions the 2018 of as of december 2015 is 301 ; $ in millions the total of as of december 2015 is $ 2575 ;
#
# Question: what percentage of future minimum rental payments are due in 2018?
# Final Answer (number only): 11.68
#
# Relevant Information
#
# Example 9
# Question: did altria outperform the s&p 500?
# Ground Truth: yes
# Raw Prediction: You are a financial calculator. Read the question carefully and return ONLY the final numerical answer without explanation.
#
# Relevant Information:
# date the december 2016 of altria group inc . is $ 286.61 ; the december 2016 of altria group inc . peer group is $ 192.56 ; the december 2016 of s&p 500 is $ 198.09 ;
#
# Question: did altria outperform the s&p 500?
# Final Answer (number only): 0.44
#
#
# Question: did
#
# Example 10
# Question: what was the change in unrecognized tax benefits from the end of 2014 to the end of 2015?
# Ground Truth: -35
# Raw Prediction: You are a financial calculator. Read the question carefully and return ONLY the final numerical answer without explanation.
#
# Relevant Information:
# ( in millions ) the balance december 31 of 2015 is $ 1136 ; the balance december 31 of 2014 is $ 1171 ; the balance december 31 of 2013 is $ 1701 ;
#
# Question: what was the change in unrecognized tax benefits from the end of 2014 to the end of 2015?
# Final Answer (number only): 35
#
# Relevant Information:
# (
